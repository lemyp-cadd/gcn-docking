# %% [markdown]
# ### Custom version of augmented_GCN for classification

# %%
# Set working directory 
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling
#  actives_c5_GCN+a+g_5_activity_atomwise_512_AID1478_train.npy
#  AID1478_test
#  AID1478_train
#  augmented_GCN_custom_4classPred_2.ipynb
#  augmented_GCN_custom_4classPred_2.py
#  blocks_mod.py
# 'Copia de augmented_GCN_custom_4classPred_2.ipynb'
# 'Copia de map_cluster_to_graph.ipynb'
#  cost_vs_epoch.png
#  drive-download-20210403T143243Z-001
#  drive-download-20210403T143243Z-001.zip
#  eval.py
#  Graph2Property_mod.py
#  helpfunc.py
#  how_to_run.gdoc
#  how_to_run.txt
#  map_cluster_to_graph.ipynb
#  __pycache__
#  roc_curve_test.png
#  roc_curve_valid.png
#  save
#  smilesToGraph_mod2.py
#  test_on_top1percent
#  train_mod.py

# %%
# Import modules 
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import numpy as np

# %tensorflow_version 1.x  # Ryu's GCN works with tf version 1.x (we should update it for tf 2)
import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x  # Ryu's GCN works with tf version 1.x (we should update it for tf 2)`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2

# %%
# Set FLAGS for environment setting / hyperparameters 
method = 'GCN+a+g'
prop = 'activity' ### CHANGED ###
database = 'AID1478_train'
num_layer = 5 # number of convolutional layers 
epoch_size = 100
learning_rate = 0.001
decay_rate = 0.95
numDB = 1   ### This is the train num_Db ###
test_numDB = 4
unit_len = 10000

flags = tf.app.flags
FLAGS = flags.FLAGS

for name in list(flags.FLAGS):
    delattr(flags.FLAGS,name)

flags.DEFINE_string('model', method, 'GCN, GCN+a, GCN+g, GCN+a+g')
flags.DEFINE_string('output', prop, '')
flags.DEFINE_string('loss_type', 'CrossEntropy', 'Options : MSE, CrossEntropy, Hinge')  ### CHANGED ###  
flags.DEFINE_string('database', database, 'Options : ZINC, ZINC2')  ### Using MSEr 
flags.DEFINE_string('optimizer', 'Adam', 'Options : Adam, SGD, RMSProp')
flags.DEFINE_string('readout', 'atomwise', 'Options : atomwise, graph_gather')
flags.DEFINE_integer('latent_dim', 512, 'Dimension of a latent vector for autoencoder')
flags.DEFINE_integer('num_layers', num_layer, '# of hidden layers')
flags.DEFINE_integer('epoch_size', epoch_size, 'Epoch size')
flags.DEFINE_integer('batch_size', 100, 'Batch size')
flags.DEFINE_integer('save_every', 1000, 'Save every')
flags.DEFINE_float('learning_rate', learning_rate, 'Batch size')
flags.DEFINE_float('decay_rate', decay_rate, 'Batch size')
flags.DEFINE_integer('num_DB', numDB, '')
flags.DEFINE_integer('unitLen', unit_len, '')
tf.app.flags.DEFINE_string('f', '', 'kernel')

modelName = FLAGS.model + '_' + str(FLAGS.num_layers) + '_' + FLAGS.output + '_' + FLAGS.readout + '_' + str(FLAGS.latent_dim) + '_' + FLAGS.database

print("model Name: ", modelName)
# Out:
# model Name:  GCN+a+g_5_activity_atomwise_512_AID1478_train

# %%
# Build the model
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from Graph2Property_mod import Graph2Property  ### CHANGED ###
tf.reset_default_graph()
tf.set_random_seed(1234)	# For reproducibility purposes, a random seed was set
model = Graph2Property(FLAGS)
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:9: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/blocks_mod.py:154: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/blocks_mod.py:108: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/blocks_mod.py:266: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:59: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:66: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:45: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:46: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:49: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:50: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:`tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# Network Ready

# %%
# restore the model if available 
path='save/'+modelName+'.ckpt'
try: 
  model.restore(path)
except Exception as e: print(e)
# Out:
# The passed save_path is not a valid checkpoint: save/GCN+a+g_5_activity_atomwise_512_AID1478_train.ckpt

# %%
# Train the model 

import train_mod 
train_cost, test_cost = train_mod.training(model, FLAGS, modelName)
# Out:
# Start Training XD
# WARNING:tensorflow:From /content/drive/My Drive/Proyectos/DEEP_LEARNING/GCNNs/Graph_CNN/augmented_gcn/classification_all-Db_undersampling/Graph2Property_mod.py:115: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# train_iter :  1 , epoch :  0 , cost :   1.4888834389155827
# train_iter :  2 , epoch :  0 , cost :   1.9540152850162549
# train_iter :  3 , epoch :  0 , cost :   1.6331496514434485
# train_iter :  4 , epoch :  0 , cost :   1.048980529996091
# test_iter :  5 , epoch :  0 , cost :   0.7446929941785777
# train_iter :  6 , epoch :  0 , cost :   0.6600268353972374
# train_iter :  7 , epoch :  0 , cost :   0.6787741671081178
# train_iter :  8 , epoch :  0 , cost :   0.9357139683929527
# train_iter :  9 , epoch :  0 , cost :   0.8380064251546885
# test_iter :  10 , epoch :  0 , cost :   0.7731216829874715
# train_iter :  11 , epoch :  0 , cost :   0.8024256946295677
# train_iter :  12 , epoch :  0 , cost :   0.6441847903415909
# train_iter :  13 , epoch :  0 , cost :   0.6032581819197486
# train_iter :  14 , epoch :  0 , cost :   0.6962513374659827
# test_iter :  15 , epoch :  0 , cost :   0.7887172198014829
# train_iter :  16 , epoch :  0 , cost :   0.8461317143486586
# train_iter :  17 , epoch :  0 , cost :   0.8012227770155144
# train_iter :  18 , epoch :  0 , cost :   0.6824556024325179
# train_iter :  19 , epoch :  0 , cost :   0.6642546875874489
# test_iter :  20 , epoch :  0 , cost :   0.6199846587143248
# time :  10.280452013015747
# 0.9361084429478377
# train_iter :  21 , epoch :  1 , cost :   0.6029733403198627
# train_iter :  22 , epoch :  1 , cost :   0.6787312759957334
# train_iter :  23 , epoch :  1 , cost :   0.6671835540373983
# train_iter :  24 , epoch :  1 , cost :   0.6896688127214695
# test_iter :  25 , epoch :  1 , cost :   0.6933546898247854
# train_iter :  26 , epoch :  1 , cost :   0.6938725566854955
# train_iter :  27 , epoch :  1 , cost :   0.6831740985178456
# train_iter :  28 , epoch :  1 , cost :   0.6498896878414054
# train_iter :  29 , epoch :  1 , cost :   0.683231302684487
# test_iter :  30 , epoch :  1 , cost :   0.6540552456818434
# train_iter :  31 , epoch :  1 , cost :   0.6087835149307859
# train_iter :  32 , epoch :  1 , cost :   0.5940345797623114
# train_iter :  33 , epoch :  1 , cost :   0.6027449816416114
# train_iter :  34 , epoch :  1 , cost :   0.6427280575481085
# test_iter :  35 , epoch :  1 , cost :   0.6714422653144925
# train_iter :  36 , epoch :  1 , cost :   0.7073460003465856
# train_iter :  37 , epoch :  1 , cost :   0.6733828393958299
# train_iter :  38 , epoch :  1 , cost :   0.6201652425855622
# train_iter :  39 , epoch :  1 , cost :   0.6348487905380417
# test_iter :  40 , epoch :  1 , cost :   0.630460984484936
# time :  8.164015054702759
# 0.6520474147220333
# train_iter :  41 , epoch :  2 , cost :   0.6195571083264353
# train_iter :  42 , epoch :  2 , cost :   0.6775500724448471
# train_iter :  43 , epoch :  2 , cost :   0.6492858442265319
# train_iter :  44 , epoch :  2 , cost :   0.6319549650667643
# test_iter :  45 , epoch :  2 , cost :   0.6428444956954172
# train_iter :  46 , epoch :  2 , cost :   0.6165084100407011
# train_iter :  47 , epoch :  2 , cost :   0.6844922108105984
# train_iter :  48 , epoch :  2 , cost :   0.6112422338011969
# train_iter :  49 , epoch :  2 , cost :   0.7200304685197924
# test_iter :  50 , epoch :  2 , cost :   0.6626348777580884
# train_iter :  51 , epoch :  2 , cost :   0.6018298580392148
# train_iter :  52 , epoch :  2 , cost :   0.5939572387331227
# train_iter :  53 , epoch :  2 , cost :   0.6016482136647335
# train_iter :  54 , epoch :  2 , cost :   0.6264654055601669
# test_iter :  55 , epoch :  2 , cost :   0.6434112595237067
# train_iter :  56 , epoch :  2 , cost :   0.667604148032407
# train_iter :  57 , epoch :  2 , cost :   0.6482131711235252
# train_iter :  58 , epoch :  2 , cost :   0.6198465327870393
# train_iter :  59 , epoch :  2 , cost :   0.6356544647376725
# test_iter :  60 , epoch :  2 , cost :   0.6251013155170162
# time :  8.454095125198364
# 0.6378650216196718
# train_iter :  61 , epoch :  3 , cost :   0.6122695350244843
# train_iter :  62 , epoch :  3 , cost :   0.6847178979538546
# train_iter :  63 , epoch :  3 , cost :   0.6409303007571406
# train_iter :  64 , epoch :  3 , cost :   0.6178007938459121
# test_iter :  65 , epoch :  3 , cost :   0.641176309136803
# train_iter :  66 , epoch :  3 , cost :   0.6102210296199645
# train_iter :  67 , epoch :  3 , cost :   0.6833712286260927
# train_iter :  68 , epoch :  3 , cost :   0.6126597630728241
# train_iter :  69 , epoch :  3 , cost :   0.7035867624790885
# test_iter :  70 , epoch :  3 , cost :   0.6557389507192665
# train_iter :  71 , epoch :  3 , cost :   0.6053666458060452
# train_iter :  72 , epoch :  3 , cost :   0.5991048793860076
# train_iter :  73 , epoch :  3 , cost :   0.6039514007113337
# train_iter :  74 , epoch :  3 , cost :   0.6258769990038746
# test_iter :  75 , epoch :  3 , cost :   0.6438899358726354
# train_iter :  76 , epoch :  3 , cost :   0.6685007689764876
# train_iter :  77 , epoch :  3 , cost :   0.6503083923643902
# train_iter :  78 , epoch :  3 , cost :   0.6178909628550067
# train_iter :  79 , epoch :  3 , cost :   0.6350080702954053
# test_iter :  80 , epoch :  3 , cost :   0.622080195122875
# time :  8.19708776473999
# 0.6357228394236195
# train_iter :  81 , epoch :  4 , cost :   0.6071180323026104
# train_iter :  82 , epoch :  4 , cost :   0.689198917954065
# train_iter :  83 , epoch :  4 , cost :   0.6405169086691336
# train_iter :  84 , epoch :  4 , cost :   0.618412435951932
# test_iter :  85 , epoch :  4 , cost :   0.6416983378526023
# train_iter :  86 , epoch :  4 , cost :   0.6132253904986148
# train_iter :  87 , epoch :  4 , cost :   0.6787600481009554
# train_iter :  88 , epoch :  4 , cost :   0.6152836685487756
# train_iter :  89 , epoch :  4 , cost :   0.6971376126689367
# test_iter :  90 , epoch :  4 , cost :   0.6546078374038423
# train_iter :  91 , epoch :  4 , cost :   0.6074733303333041
# train_iter :  92 , epoch :  4 , cost :   0.6001472806829344
# train_iter :  93 , epoch :  4 , cost :   0.6032569508691569
# train_iter :  94 , epoch :  4 , cost :   0.6259358924065349
# test_iter :  95 , epoch :  4 , cost :   0.6458502162701649
# train_iter :  96 , epoch :  4 , cost :   0.6718187269267061
# train_iter :  97 , epoch :  4 , cost :   0.6525715031922666
# train_iter :  98 , epoch :  4 , cost :   0.6174327258255358
# train_iter :  99 , epoch :  4 , cost :   0.6354567625759254
# test_iter :  100 , epoch :  4 , cost :   0.6221919539382458
# cross entropy :  0.622191953938246
# time :  8.57489013671875
# 0.6358591367192117
# train_iter :  101 , epoch :  5 , cost :   0.606577691371087
# train_iter :  102 , epoch :  5 , cost :   0.6887540623029134
# train_iter :  103 , epoch :  5 , cost :   0.6405050130670719
# train_iter :  104 , epoch :  5 , cost :   0.6202969224908501
# test_iter :  105 , epoch :  5 , cost :   0.6423908223546734
# train_iter :  106 , epoch :  5 , cost :   0.6159403758794468
# train_iter :  107 , epoch :  5 , cost :   0.6767644601318717
# train_iter :  108 , epoch :  5 , cost :   0.6164326774547927
# train_iter :  109 , epoch :  5 , cost :   0.6961286767144091
# test_iter :  110 , epoch :  5 , cost :   0.6547157564787415
# train_iter :  111 , epoch :  5 , cost :   0.6072715847829724
# train_iter :  112 , epoch :  5 , cost :   0.5991256739672239
# train_iter :  113 , epoch :  5 , cost :   0.6019465997494453
# train_iter :  114 , epoch :  5 , cost :   0.6260539261921266
# test_iter :  115 , epoch :  5 , cost :   0.6468872537623958
# train_iter :  116 , epoch :  5 , cost :   0.6733929467082181
# train_iter :  117 , epoch :  5 , cost :   0.6530282479658709
# train_iter :  118 , epoch :  5 , cost :   0.6170186165489548
# train_iter :  119 , epoch :  5 , cost :   0.6355814633769462
# test_iter :  120 , epoch :  5 , cost :   0.6228909544754964
# time :  8.154946327209473
# 0.6359261836690125
# train_iter :  121 , epoch :  6 , cost :   0.6069912600267989
# train_iter :  122 , epoch :  6 , cost :   0.6879816870807628
# train_iter :  123 , epoch :  6 , cost :   0.6404762593222761
# train_iter :  124 , epoch :  6 , cost :   0.6213401373502118
# test_iter :  125 , epoch :  6 , cost :   0.6426149411417144
# train_iter :  126 , epoch :  6 , cost :   0.6171551357744406
# train_iter :  127 , epoch :  6 , cost :   0.6759572208837432
# train_iter :  128 , epoch :  6 , cost :   0.6166397142934554
# train_iter :  129 , epoch :  6 , cost :   0.6962615242694106
# test_iter :  130 , epoch :  6 , cost :   0.6549039280187625
# train_iter :  131 , epoch :  6 , cost :   0.6067224321357859
# train_iter :  132 , epoch :  6 , cost :   0.5981700844987591
# train_iter :  133 , epoch :  6 , cost :   0.6007586544547343
# train_iter :  134 , epoch :  6 , cost :   0.6259022209044002
# test_iter :  135 , epoch :  6 , cost :   0.6470158866000592
# train_iter :  136 , epoch :  6 , cost :   0.6735391736621886
# train_iter :  137 , epoch :  6 , cost :   0.6524015453314911
# train_iter :  138 , epoch :  6 , cost :   0.6163422468204143
# train_iter :  139 , epoch :  6 , cost :   0.6356058959027223
# test_iter :  140 , epoch :  6 , cost :   0.623810328246935
# time :  8.572200059890747
# 0.6357653245444748
# train_iter :  141 , epoch :  7 , cost :   0.6073408654968674
# train_iter :  142 , epoch :  7 , cost :   0.6865520202655371
# train_iter :  143 , epoch :  7 , cost :   0.6401494570715641
# train_iter :  144 , epoch :  7 , cost :   0.6213789743106942
# test_iter :  145 , epoch :  7 , cost :   0.6423080465765313
# train_iter :  146 , epoch :  7 , cost :   0.6172621377941049
# train_iter :  147 , epoch :  7 , cost :   0.6754942648161548
# train_iter :  148 , epoch :  7 , cost :   0.6163616306133686
# train_iter :  149 , epoch :  7 , cost :   0.6965701997194396
# test_iter :  150 , epoch :  7 , cost :   0.6550220215780814
# train_iter :  151 , epoch :  7 , cost :   0.6061870796625866
# train_iter :  152 , epoch :  7 , cost :   0.5973685179609446
# train_iter :  153 , epoch :  7 , cost :   0.5994214728843653
# train_iter :  154 , epoch :  7 , cost :   0.6253830505628335
# test_iter :  155 , epoch :  7 , cost :   0.6463693547927476
# train_iter :  156 , epoch :  7 , cost :   0.6725724077609462
# train_iter :  157 , epoch :  7 , cost :   0.6506250635303849
# train_iter :  158 , epoch :  7 , cost :   0.6150547642495201
# train_iter :  159 , epoch :  7 , cost :   0.6355742833676585
# test_iter :  160 , epoch :  7 , cost :   0.6256349488636618
# time :  8.267105340957642
# 0.6352060118791857
# train_iter :  161 , epoch :  8 , cost :   0.6080519690235784
# train_iter :  162 , epoch :  8 , cost :   0.6850425845347726
# train_iter :  163 , epoch :  8 , cost :   0.6391671447595848
# train_iter :  164 , epoch :  8 , cost :   0.6208231366818437
# test_iter :  165 , epoch :  8 , cost :   0.6410741166693132
# train_iter :  166 , epoch :  8 , cost :   0.6158771648391886
# train_iter :  167 , epoch :  8 , cost :   0.6767346711903325
# train_iter :  168 , epoch :  8 , cost :   0.6140383603707492
# train_iter :  169 , epoch :  8 , cost :   0.7013788056433009
# test_iter :  170 , epoch :  8 , cost :   0.6549442811528359
# train_iter :  171 , epoch :  8 , cost :   0.6053663740795298
# train_iter :  172 , epoch :  8 , cost :   0.5978215972966623
# train_iter :  173 , epoch :  8 , cost :   0.5985419226041675
# train_iter :  174 , epoch :  8 , cost :   0.6236752961372471
# test_iter :  175 , epoch :  8 , cost :   0.6432480342600289
# train_iter :  176 , epoch :  8 , cost :   0.6679974795248572
# train_iter :  177 , epoch :  8 , cost :   0.644922867569887
# train_iter :  178 , epoch :  8 , cost :   0.6123415245789584
# train_iter :  179 , epoch :  8 , cost :   0.6351518598214735
# test_iter :  180 , epoch :  8 , cost :   0.6290448960463548
# time :  8.617034673690796
# 0.6341832974160083
# train_iter :  181 , epoch :  9 , cost :   0.6098928375661394
# train_iter :  182 , epoch :  9 , cost :   0.6821529256954105
# train_iter :  183 , epoch :  9 , cost :   0.636881409189444
# train_iter :  184 , epoch :  9 , cost :   0.6159585367311425
# test_iter :  185 , epoch :  9 , cost :   0.6383424107483211
# train_iter :  186 , epoch :  9 , cost :   0.6103574548156517
# train_iter :  187 , epoch :  9 , cost :   0.6801033577221998
# train_iter :  188 , epoch :  9 , cost :   0.611751766511552
# train_iter :  189 , epoch :  9 , cost :   0.6988052653862431
# test_iter :  190 , epoch :  9 , cost :   0.6534584030232392
# train_iter :  191 , epoch :  9 , cost :   0.6046225245709329
# train_iter :  192 , epoch :  9 , cost :   0.5960372581919655
# train_iter :  193 , epoch :  9 , cost :   0.594628553369124
# train_iter :  194 , epoch :  9 , cost :   0.6203128852770551
# test_iter :  195 , epoch :  9 , cost :   0.6384980986500657
# train_iter :  196 , epoch :  9 , cost :   0.6631149375113694
# train_iter :  197 , epoch :  9 , cost :   0.6365110689660934
# train_iter :  198 , epoch :  9 , cost :   0.6063583141551885
# train_iter :  199 , epoch :  9 , cost :   0.6329845257943861
# test_iter :  200 , epoch :  9 , cost :   0.6311516535585278
# cross entropy :  0.6311516535585278
# time :  8.251627683639526
# 0.6312796013408686
# train_iter :  201 , epoch :  10 , cost :   0.6109134114228215
# train_iter :  202 , epoch :  10 , cost :   0.6758484592997027
# train_iter :  203 , epoch :  10 , cost :   0.6321706120061582
# train_iter :  204 , epoch :  10 , cost :   0.6093043276800003
# test_iter :  205 , epoch :  10 , cost :   0.6344661052472362
# train_iter :  206 , epoch :  10 , cost :   0.6058048200182043
# train_iter :  207 , epoch :  10 , cost :   0.6761853003310592
# train_iter :  208 , epoch :  10 , cost :   0.6084405526603012
# train_iter :  209 , epoch :  10 , cost :   0.6867723063190041
# test_iter :  210 , epoch :  10 , cost :   0.6489204025060025
# train_iter :  211 , epoch :  10 , cost :   0.6026409163172253
# train_iter :  212 , epoch :  10 , cost :   0.589976153555423
# train_iter :  213 , epoch :  10 , cost :   0.5855520617117326
# train_iter :  214 , epoch :  10 , cost :   0.6136653366665327
# test_iter :  215 , epoch :  10 , cost :   0.6268777307300455
# train_iter :  216 , epoch :  10 , cost :   0.6561239613521163
# train_iter :  217 , epoch :  10 , cost :   0.6126775773419457
# train_iter :  218 , epoch :  10 , cost :   0.6044591289912243
# train_iter :  219 , epoch :  10 , cost :   0.6304292839265536
# test_iter :  220 , epoch :  10 , cost :   0.6251538613013257
# time :  8.1851224899292
# 0.6250602631000004
# train_iter :  221 , epoch :  11 , cost :   0.6027912787001548
# train_iter :  222 , epoch :  11 , cost :   0.6931219467409927
# train_iter :  223 , epoch :  11 , cost :   0.6325937724321833
# train_iter :  224 , epoch :  11 , cost :   0.591876822082726
# test_iter :  225 , epoch :  11 , cost :   0.6247097049539452
# train_iter :  226 , epoch :  11 , cost :   0.5955725906335713
# train_iter :  227 , epoch :  11 , cost :   0.6546661147157757
# train_iter :  228 , epoch :  11 , cost :   0.6091437720161702
# train_iter :  229 , epoch :  11 , cost :   0.6380074479374708
# test_iter :  230 , epoch :  11 , cost :   0.6345456040694711
# train_iter :  231 , epoch :  11 , cost :   0.6004795567988063
# train_iter :  232 , epoch :  11 , cost :   0.5729429077171722
# train_iter :  233 , epoch :  11 , cost :   0.5669019738374375
# train_iter :  234 , epoch :  11 , cost :   0.6092706289275412
# test_iter :  235 , epoch :  11 , cost :   0.6019304705768408
# train_iter :  236 , epoch :  11 , cost :   0.644733806655823
# train_iter :  237 , epoch :  11 , cost :   0.5852000768108971
# train_iter :  238 , epoch :  11 , cost :   0.608826087383374
# train_iter :  239 , epoch :  11 , cost :   0.623439396897767
# test_iter :  240 , epoch :  11 , cost :   0.6167953337512552
# time :  8.190279722213745
# 0.6143480112679914
# train_iter :  241 , epoch :  12 , cost :   0.5899437312794436
# train_iter :  242 , epoch :  12 , cost :   0.7153792977404752
# train_iter :  243 , epoch :  12 , cost :   0.6332133792338849
# train_iter :  244 , epoch :  12 , cost :   0.576019999272879
# test_iter :  245 , epoch :  12 , cost :   0.6113142982284345
# train_iter :  246 , epoch :  12 , cost :   0.5806537570520167
# train_iter :  247 , epoch :  12 , cost :   0.6403128823922003
# train_iter :  248 , epoch :  12 , cost :   0.5989783713119348
# train_iter :  249 , epoch :  12 , cost :   0.6057879984990713
# test_iter :  250 , epoch :  12 , cost :   0.6193433509193887
# train_iter :  251 , epoch :  12 , cost :   0.5839608146849139
# train_iter :  252 , epoch :  12 , cost :   0.560465164906363
# train_iter :  253 , epoch :  12 , cost :   0.537551955408892
# train_iter :  254 , epoch :  12 , cost :   0.5783991025127366
# test_iter :  255 , epoch :  12 , cost :   0.5634697220674552
# train_iter :  256 , epoch :  12 , cost :   0.610794243327396
# train_iter :  257 , epoch :  12 , cost :   0.5634734884718927
# train_iter :  258 , epoch :  12 , cost :   0.5841688501809463
# train_iter :  259 , epoch :  12 , cost :   0.6028541475126484
# test_iter :  260 , epoch :  12 , cost :   0.6100922913517394
# time :  8.157613039016724
# 0.5976223239867309
# train_iter :  261 , epoch :  13 , cost :   0.5721708312771988
# train_iter :  262 , epoch :  13 , cost :   0.7137925192401247
# train_iter :  263 , epoch :  13 , cost :   0.6083634377069116
# train_iter :  264 , epoch :  13 , cost :   0.5641648471769766
# test_iter :  265 , epoch :  13 , cost :   0.6084380729783119
# train_iter :  266 , epoch :  13 , cost :   0.5798615712461141
# train_iter :  267 , epoch :  13 , cost :   0.6305808099565019
# train_iter :  268 , epoch :  13 , cost :   0.5560156975880666
# train_iter :  269 , epoch :  13 , cost :   0.607547251653755
# test_iter :  270 , epoch :  13 , cost :   0.594482600093351
# train_iter :  271 , epoch :  13 , cost :   0.5742262147928165
# train_iter :  272 , epoch :  13 , cost :   0.5593980739749086
# train_iter :  273 , epoch :  13 , cost :   0.5113967940550015
# train_iter :  274 , epoch :  13 , cost :   0.5429073973971158
# test_iter :  275 , epoch :  13 , cost :   0.5424584750525675
# train_iter :  276 , epoch :  13 , cost :   0.6031634363909784
# train_iter :  277 , epoch :  13 , cost :   0.5292447165120864
# train_iter :  278 , epoch :  13 , cost :   0.5680828490676
# train_iter :  279 , epoch :  13 , cost :   0.609616764565946
# test_iter :  280 , epoch :  13 , cost :   0.6043638739738555
# time :  8.25418758392334
# 0.5831583257876314
# train_iter :  281 , epoch :  14 , cost :   0.564409940643127
# train_iter :  282 , epoch :  14 , cost :   0.6899169707301017
# train_iter :  283 , epoch :  14 , cost :   0.6037772316149874
# train_iter :  284 , epoch :  14 , cost :   0.5433177535928979
# test_iter :  285 , epoch :  14 , cost :   0.5966752886586992
# train_iter :  286 , epoch :  14 , cost :   0.5447844109008109
# train_iter :  287 , epoch :  14 , cost :   0.6246331879539934
# train_iter :  288 , epoch :  14 , cost :   0.5548968475838163
# train_iter :  289 , epoch :  14 , cost :   0.5594236142943535
# test_iter :  290 , epoch :  14 , cost :   0.5861679443376713
# train_iter :  291 , epoch :  14 , cost :   0.5692882481132618
# train_iter :  292 , epoch :  14 , cost :   0.5419018322533631
# train_iter :  293 , epoch :  14 , cost :   0.48876105196352254
# train_iter :  294 , epoch :  14 , cost :   0.5118745429015108
# test_iter :  295 , epoch :  14 , cost :   0.5138017843636831
# train_iter :  296 , epoch :  14 , cost :   0.5655897212516728
# train_iter :  297 , epoch :  14 , cost :   0.5178218192140396
# train_iter :  298 , epoch :  14 , cost :   0.5575634530932412
# train_iter :  299 , epoch :  14 , cost :   0.6120541829215874
# test_iter :  300 , epoch :  14 , cost :   0.5990977133471088
# cross entropy :  0.5990977133471089
# time :  8.143833637237549
# 0.5656259255641429
# train_iter :  301 , epoch :  15 , cost :   0.5571159935611626
# train_iter :  302 , epoch :  15 , cost :   0.6723857127938712
# train_iter :  303 , epoch :  15 , cost :   0.5822897226570761
# train_iter :  304 , epoch :  15 , cost :   0.5375998294367813
# test_iter :  305 , epoch :  15 , cost :   0.5896591512109064
# train_iter :  306 , epoch :  15 , cost :   0.5350608330270485
# train_iter :  307 , epoch :  15 , cost :   0.6260330161210296
# train_iter :  308 , epoch :  15 , cost :   0.5397934398207306
# train_iter :  309 , epoch :  15 , cost :   0.5439683020391306
# test_iter :  310 , epoch :  15 , cost :   0.5823492160564864
# train_iter :  311 , epoch :  15 , cost :   0.5667060867699444
# train_iter :  312 , epoch :  15 , cost :   0.5356919219296398
# train_iter :  313 , epoch :  15 , cost :   0.47712551493384636
# train_iter :  314 , epoch :  15 , cost :   0.4866215682322904
# test_iter :  315 , epoch :  15 , cost :   0.5065219109733252
# train_iter :  316 , epoch :  15 , cost :   0.5502902742831101
# train_iter :  317 , epoch :  15 , cost :   0.50446823055032
# train_iter :  318 , epoch :  15 , cost :   0.5339231629616628
# train_iter :  319 , epoch :  15 , cost :   0.6166446537082962
# test_iter :  320 , epoch :  15 , cost :   0.5912771746878782
# time :  8.143078327178955
# 0.5541073914266212
# train_iter :  321 , epoch :  16 , cost :   0.5559706062746987
# train_iter :  322 , epoch :  16 , cost :   0.638009421462218
# train_iter :  323 , epoch :  16 , cost :   0.5706994160487294
# train_iter :  324 , epoch :  16 , cost :   0.5169426676683585
# test_iter :  325 , epoch :  16 , cost :   0.5728803233338187
# train_iter :  326 , epoch :  16 , cost :   0.4989995338967035
# train_iter :  327 , epoch :  16 , cost :   0.6199318815881739
# train_iter :  328 , epoch :  16 , cost :   0.5426986332048575
# train_iter :  329 , epoch :  16 , cost :   0.5153050705720734
# test_iter :  330 , epoch :  16 , cost :   0.572149522766062
# train_iter :  331 , epoch :  16 , cost :   0.5672216411021275
# train_iter :  332 , epoch :  16 , cost :   0.5239246684247392
# train_iter :  333 , epoch :  16 , cost :   0.4603714802471907
# train_iter :  334 , epoch :  16 , cost :   0.46805308597457684
# test_iter :  335 , epoch :  16 , cost :   0.4911887956842406
# train_iter :  336 , epoch :  16 , cost :   0.5303237450253246
# train_iter :  337 , epoch :  16 , cost :   0.49398421745251975
# train_iter :  338 , epoch :  16 , cost :   0.5178131777060427
# train_iter :  339 , epoch :  16 , cost :   0.6096060016560435
# test_iter :  340 , epoch :  16 , cost :   0.5891799812080504
# time :  8.10974645614624
# 0.5393659530190236
# train_iter :  341 , epoch :  17 , cost :   0.5515513517046164
# train_iter :  342 , epoch :  17 , cost :   0.6267565239846806
# train_iter :  343 , epoch :  17 , cost :   0.5640807762682948
# train_iter :  344 , epoch :  17 , cost :   0.511133662922995
# test_iter :  345 , epoch :  17 , cost :   0.5728805360541881
# train_iter :  346 , epoch :  17 , cost :   0.48939306666040466
# train_iter :  347 , epoch :  17 , cost :   0.6154600138462003
# train_iter :  348 , epoch :  17 , cost :   0.5301471451211291
# train_iter :  349 , epoch :  17 , cost :   0.5056961106992427
# test_iter :  350 , epoch :  17 , cost :   0.5611889482013139
# train_iter :  351 , epoch :  17 , cost :   0.5693460766557318
# train_iter :  352 , epoch :  17 , cost :   0.522680106371802
# train_iter :  353 , epoch :  17 , cost :   0.4484633530174925
# train_iter :  354 , epoch :  17 , cost :   0.4579461494338527
# test_iter :  355 , epoch :  17 , cost :   0.4842779144381319
# train_iter :  356 , epoch :  17 , cost :   0.5300518113457096
# train_iter :  357 , epoch :  17 , cost :   0.4815991472928712
# train_iter :  358 , epoch :  17 , cost :   0.5136235406371356
# train_iter :  359 , epoch :  17 , cost :   0.605004562933705
# test_iter :  360 , epoch :  17 , cost :   0.5856492525516181
# time :  8.146316766738892
# 0.5326833374309915
# train_iter :  361 , epoch :  18 , cost :   0.5503159539621063
# train_iter :  362 , epoch :  18 , cost :   0.6215333799794596
# train_iter :  363 , epoch :  18 , cost :   0.5651285514986065
# train_iter :  364 , epoch :  18 , cost :   0.5000184933542215
# test_iter :  365 , epoch :  18 , cost :   0.5697863764417553
# train_iter :  366 , epoch :  18 , cost :   0.48154154623265244
# train_iter :  367 , epoch :  18 , cost :   0.6033896711684662
# train_iter :  368 , epoch :  18 , cost :   0.533688536774816
# train_iter :  369 , epoch :  18 , cost :   0.4933927960433246
# test_iter :  370 , epoch :  18 , cost :   0.5640189849735817
# train_iter :  371 , epoch :  18 , cost :   0.5643719539209254
# train_iter :  372 , epoch :  18 , cost :   0.5166373299483191
# train_iter :  373 , epoch :  18 , cost :   0.4412002139373305
# train_iter :  374 , epoch :  18 , cost :   0.44977039106286937
# test_iter :  375 , epoch :  18 , cost :   0.47431149178158394
# train_iter :  376 , epoch :  18 , cost :   0.523497482453821
# train_iter :  377 , epoch :  18 , cost :   0.47274356670140266
# train_iter :  378 , epoch :  18 , cost :   0.5043521962477656
# train_iter :  379 , epoch :  18 , cost :   0.5977316667704105
# test_iter :  380 , epoch :  18 , cost :   0.579429818516516
# time :  8.058626413345337
# 0.5262071081285311
# train_iter :  381 , epoch :  19 , cost :   0.5476450283240137
# train_iter :  382 , epoch :  19 , cost :   0.6130223626924013
# train_iter :  383 , epoch :  19 , cost :   0.558740570332514
# train_iter :  384 , epoch :  19 , cost :   0.4930480653949519
# test_iter :  385 , epoch :  19 , cost :   0.5669472113823443
# train_iter :  386 , epoch :  19 , cost :   0.47091160757625544
# train_iter :  387 , epoch :  19 , cost :   0.5948280048150174
# train_iter :  388 , epoch :  19 , cost :   0.5268199083530718
# train_iter :  389 , epoch :  19 , cost :   0.48462083834674496
# test_iter :  390 , epoch :  19 , cost :   0.5563077605042591
# train_iter :  391 , epoch :  19 , cost :   0.562261092643634
# train_iter :  392 , epoch :  19 , cost :   0.5146926830117251
# train_iter :  393 , epoch :  19 , cost :   0.43333860718497147
# train_iter :  394 , epoch :  19 , cost :   0.4425167675564279
# test_iter :  395 , epoch :  19 , cost :   0.4708157517435073
# train_iter :  396 , epoch :  19 , cost :   0.5238943423118885
# train_iter :  397 , epoch :  19 , cost :   0.4607101514383069
# train_iter :  398 , epoch :  19 , cost :   0.4987433679768752
# train_iter :  399 , epoch :  19 , cost :   0.5891449052177345
# test_iter :  400 , epoch :  19 , cost :   0.5760825725419929
# cross entropy :  0.5760825725419929
# time :  8.15610408782959
# 0.5196836439485334
# train_iter :  401 , epoch :  20 , cost :   0.5461172798717999
# train_iter :  402 , epoch :  20 , cost :   0.6077509604757507
# train_iter :  403 , epoch :  20 , cost :   0.5571405361206146
# train_iter :  404 , epoch :  20 , cost :   0.487868367595599
# test_iter :  405 , epoch :  20 , cost :   0.5650505756911413
# train_iter :  406 , epoch :  20 , cost :   0.46165969984272737
# train_iter :  407 , epoch :  20 , cost :   0.586815219452571
# train_iter :  408 , epoch :  20 , cost :   0.5281847445783981
# train_iter :  409 , epoch :  20 , cost :   0.4719711268851113
# test_iter :  410 , epoch :  20 , cost :   0.5536626961359693
# train_iter :  411 , epoch :  20 , cost :   0.5589386947251163
# train_iter :  412 , epoch :  20 , cost :   0.5123524059757836
# train_iter :  413 , epoch :  20 , cost :   0.42670057339111056
# train_iter :  414 , epoch :  20 , cost :   0.4381746865244698
# test_iter :  415 , epoch :  20 , cost :   0.46568406732107
# train_iter :  416 , epoch :  20 , cost :   0.5221252028361129
# train_iter :  417 , epoch :  20 , cost :   0.45412502140397665
# train_iter :  418 , epoch :  20 , cost :   0.494641178607081
# train_iter :  419 , epoch :  20 , cost :   0.5831202390810434
# test_iter :  420 , epoch :  20 , cost :   0.5716416186573703
# time :  8.23500394821167
# 0.5148553710854542
# train_iter :  421 , epoch :  21 , cost :   0.5445727287694874
# train_iter :  422 , epoch :  21 , cost :   0.6031306004123734
# train_iter :  423 , epoch :  21 , cost :   0.5555129502750336
# train_iter :  424 , epoch :  21 , cost :   0.479696113978834
# test_iter :  425 , epoch :  21 , cost :   0.5654229110019493
# train_iter :  426 , epoch :  21 , cost :   0.4536947931633739
# train_iter :  427 , epoch :  21 , cost :   0.5787573906458551
# train_iter :  428 , epoch :  21 , cost :   0.5274160537012862
# train_iter :  429 , epoch :  21 , cost :   0.4634023541961856
# test_iter :  430 , epoch :  21 , cost :   0.5523714469125351
# train_iter :  431 , epoch :  21 , cost :   0.5544632994870754
# train_iter :  432 , epoch :  21 , cost :   0.5112990566263379
# train_iter :  433 , epoch :  21 , cost :   0.4215540766185773
# train_iter :  434 , epoch :  21 , cost :   0.43371685567792784
# test_iter :  435 , epoch :  21 , cost :   0.46159681342265785
# train_iter :  436 , epoch :  21 , cost :   0.5211189704080419
# train_iter :  437 , epoch :  21 , cost :   0.45065020221615293
# train_iter :  438 , epoch :  21 , cost :   0.49393066754326737
# train_iter :  439 , epoch :  21 , cost :   0.5773869356652392
# test_iter :  440 , epoch :  21 , cost :   0.5713022888553807
# time :  8.272727251052856
# 0.5106439405865655
# train_iter :  441 , epoch :  22 , cost :   0.5419654660526061
# train_iter :  442 , epoch :  22 , cost :   0.596733141457068
# train_iter :  443 , epoch :  22 , cost :   0.5549031612012254
# train_iter :  444 , epoch :  22 , cost :   0.47371118694801856
# test_iter :  445 , epoch :  22 , cost :   0.5653155986593643
# train_iter :  446 , epoch :  22 , cost :   0.4475436563767768
# train_iter :  447 , epoch :  22 , cost :   0.5706381412681119
# train_iter :  448 , epoch :  22 , cost :   0.530341236169046
# train_iter :  449 , epoch :  22 , cost :   0.45292144487432184
# test_iter :  450 , epoch :  22 , cost :   0.5516269959859825
# train_iter :  451 , epoch :  22 , cost :   0.5485887091044056
# train_iter :  452 , epoch :  22 , cost :   0.5098946937837953
# train_iter :  453 , epoch :  22 , cost :   0.4174841870273166
# train_iter :  454 , epoch :  22 , cost :   0.43075898755648223
# test_iter :  455 , epoch :  22 , cost :   0.4585011688781562
# train_iter :  456 , epoch :  22 , cost :   0.5195030741179718
# train_iter :  457 , epoch :  22 , cost :   0.4479926014527635
# train_iter :  458 , epoch :  22 , cost :   0.49313670289839334
# train_iter :  459 , epoch :  22 , cost :   0.5753456528477102
# test_iter :  460 , epoch :  22 , cost :   0.5668367275695152
# time :  8.131957769393921
# 0.5069663776960008
# train_iter :  461 , epoch :  23 , cost :   0.5394850320255989
# train_iter :  462 , epoch :  23 , cost :   0.593694989303516
# train_iter :  463 , epoch :  23 , cost :   0.5549463211799981
# train_iter :  464 , epoch :  23 , cost :   0.46518582085449767
# test_iter :  465 , epoch :  23 , cost :   0.5639888131270824
# train_iter :  466 , epoch :  23 , cost :   0.438329523137088
# train_iter :  467 , epoch :  23 , cost :   0.5617009146151966
# train_iter :  468 , epoch :  23 , cost :   0.5383165265692255
# train_iter :  469 , epoch :  23 , cost :   0.44267213790266113
# test_iter :  470 , epoch :  23 , cost :   0.551475284530636
# train_iter :  471 , epoch :  23 , cost :   0.5459532478980791
# train_iter :  472 , epoch :  23 , cost :   0.5084243447340442
# train_iter :  473 , epoch :  23 , cost :   0.4155805816221505
# train_iter :  474 , epoch :  23 , cost :   0.42840307119469173
# test_iter :  475 , epoch :  23 , cost :   0.45557593145247083
# train_iter :  476 , epoch :  23 , cost :   0.5171089655658955
# train_iter :  477 , epoch :  23 , cost :   0.4466465828609092
# train_iter :  478 , epoch :  23 , cost :   0.4969422690916504
# train_iter :  479 , epoch :  23 , cost :   0.5739915457140005
# test_iter :  480 , epoch :  23 , cost :   0.5646906796590178
# time :  8.195642471313477
# 0.5042113671418251
# train_iter :  481 , epoch :  24 , cost :   0.5372061744281471
# train_iter :  482 , epoch :  24 , cost :   0.5859686778990963
# train_iter :  483 , epoch :  24 , cost :   0.5586431582971733
# train_iter :  484 , epoch :  24 , cost :   0.4614267045696762
# test_iter :  485 , epoch :  24 , cost :   0.5615020861533876
# train_iter :  486 , epoch :  24 , cost :   0.426179198862416
# train_iter :  487 , epoch :  24 , cost :   0.5547665014666999
# train_iter :  488 , epoch :  24 , cost :   0.5474374179868058
# train_iter :  489 , epoch :  24 , cost :   0.4361579855845898
# test_iter :  490 , epoch :  24 , cost :   0.544691903318371
# train_iter :  491 , epoch :  24 , cost :   0.5423244893281313
# train_iter :  492 , epoch :  24 , cost :   0.5069712082279704
# train_iter :  493 , epoch :  24 , cost :   0.41734172908234707
# train_iter :  494 , epoch :  24 , cost :   0.43605778821029545
# test_iter :  495 , epoch :  24 , cost :   0.4591651260988109
# train_iter :  496 , epoch :  24 , cost :   0.5207271727934762
# train_iter :  497 , epoch :  24 , cost :   0.4459562017683211
# train_iter :  498 , epoch :  24 , cost :   0.5019975025503234
# train_iter :  499 , epoch :  24 , cost :   0.5821812369068867
# test_iter :  500 , epoch :  24 , cost :   0.5637387174967756
# cross entropy :  0.5637387174967757
# time :  8.093167066574097
# 0.5038339467476473
# train_iter :  501 , epoch :  25 , cost :   0.5413681850799282
# train_iter :  502 , epoch :  25 , cost :   0.5766524622485734
# train_iter :  503 , epoch :  25 , cost :   0.562091435917689
# train_iter :  504 , epoch :  25 , cost :   0.4646088623516491
# test_iter :  505 , epoch :  25 , cost :   0.5622992862353301
# train_iter :  506 , epoch :  25 , cost :   0.418644756029177
# train_iter :  507 , epoch :  25 , cost :   0.5503375683803894
# train_iter :  508 , epoch :  25 , cost :   0.5651309099196753
# train_iter :  509 , epoch :  25 , cost :   0.43574087381587473
# test_iter :  510 , epoch :  25 , cost :   0.5411922979841784
# train_iter :  511 , epoch :  25 , cost :   0.5444629228951798
# train_iter :  512 , epoch :  25 , cost :   0.5023377709335148
# train_iter :  513 , epoch :  25 , cost :   0.4184672027535828
# train_iter :  514 , epoch :  25 , cost :   0.45391826487714204
# test_iter :  515 , epoch :  25 , cost :   0.47873360815347427
# train_iter :  516 , epoch :  25 , cost :   0.5395739830496944
# train_iter :  517 , epoch :  25 , cost :   0.4398394597076839
# train_iter :  518 , epoch :  25 , cost :   0.4968224004628921
# train_iter :  519 , epoch :  25 , cost :   0.6077991260390092
# test_iter :  520 , epoch :  25 , cost :   0.5848710571990823
# time :  8.235608577728271
# 0.5073622615288534
# train_iter :  521 , epoch :  26 , cost :   0.5794639094031423
# train_iter :  522 , epoch :  26 , cost :   0.5483582512856319
# train_iter :  523 , epoch :  26 , cost :   0.5569298010180473
# train_iter :  524 , epoch :  26 , cost :   0.477325649627023
# test_iter :  525 , epoch :  26 , cost :   0.581108945951259
# train_iter :  526 , epoch :  26 , cost :   0.4309719136546308
# train_iter :  527 , epoch :  26 , cost :   0.5749641490262596
# train_iter :  528 , epoch :  26 , cost :   0.5422070270744331
# train_iter :  529 , epoch :  26 , cost :   0.44873483168401196
# test_iter :  530 , epoch :  26 , cost :   0.5630800910054857
# train_iter :  531 , epoch :  26 , cost :   0.5914019024042257
# train_iter :  532 , epoch :  26 , cost :   0.5232135761815515
# train_iter :  533 , epoch :  26 , cost :   0.41151239752957525
# train_iter :  534 , epoch :  26 , cost :   0.4504174809443786
# test_iter :  535 , epoch :  26 , cost :   0.5329285880814278
# train_iter :  536 , epoch :  26 , cost :   0.5915402205203072
# train_iter :  537 , epoch :  26 , cost :   0.49247517847675665
# train_iter :  538 , epoch :  26 , cost :   0.4581482456738776
# train_iter :  539 , epoch :  26 , cost :   0.582921949225534
# test_iter :  540 , epoch :  26 , cost :   0.6234153608530982
# time :  8.150988340377808
# 0.5162866552330867
# train_iter :  541 , epoch :  27 , cost :   0.6341623184197417
# train_iter :  542 , epoch :  27 , cost :   0.5606690315187002
# train_iter :  543 , epoch :  27 , cost :   0.5603161343655743
# train_iter :  544 , epoch :  27 , cost :   0.4497282035881403
# test_iter :  545 , epoch :  27 , cost :   0.5719818212810014
# train_iter :  546 , epoch :  27 , cost :   0.42121469778972953
# train_iter :  547 , epoch :  27 , cost :   0.6412743674812134
# train_iter :  548 , epoch :  27 , cost :   0.49604327554837147
# train_iter :  549 , epoch :  27 , cost :   0.4655592590989116
# test_iter :  550 , epoch :  27 , cost :   0.5553171382795561
# train_iter :  551 , epoch :  27 , cost :   0.5340806143216128
# train_iter :  552 , epoch :  27 , cost :   0.5215328952696899
# train_iter :  553 , epoch :  27 , cost :   0.4486574058921835
# train_iter :  554 , epoch :  27 , cost :   0.4211867452964094
# test_iter :  555 , epoch :  27 , cost :   0.4541799621432123
# train_iter :  556 , epoch :  27 , cost :   0.5069432234943082
# train_iter :  557 , epoch :  27 , cost :   0.46050219994114955
# train_iter :  558 , epoch :  27 , cost :   0.4688956825619966
# train_iter :  559 , epoch :  27 , cost :   0.5555796448944266
# test_iter :  560 , epoch :  27 , cost :   0.5517781612120058
# time :  8.39893627166748
# 0.5091466062176349
# train_iter :  561 , epoch :  28 , cost :   0.532192017336478
# train_iter :  562 , epoch :  28 , cost :   0.5320653539262352
# train_iter :  563 , epoch :  28 , cost :   0.5400444254340776
# train_iter :  564 , epoch :  28 , cost :   0.4383619522208055
# test_iter :  565 , epoch :  28 , cost :   0.5446782604330793
# train_iter :  566 , epoch :  28 , cost :   0.40483905818996335
# train_iter :  567 , epoch :  28 , cost :   0.5646170646761121
# train_iter :  568 , epoch :  28 , cost :   0.47994610393659753
# train_iter :  569 , epoch :  28 , cost :   0.430160529465884
# test_iter :  570 , epoch :  28 , cost :   0.5382211914712491
# train_iter :  571 , epoch :  28 , cost :   0.5314235402680427
# train_iter :  572 , epoch :  28 , cost :   0.5045902652053647
# train_iter :  573 , epoch :  28 , cost :   0.39977233716714367
# train_iter :  574 , epoch :  28 , cost :   0.4006338301859621
# test_iter :  575 , epoch :  28 , cost :   0.4593942517637379
# train_iter :  576 , epoch :  28 , cost :   0.5167421395673931
# train_iter :  577 , epoch :  28 , cost :   0.438887303563915
# train_iter :  578 , epoch :  28 , cost :   0.46426487489177215
# train_iter :  579 , epoch :  28 , cost :   0.5641604842810348
# test_iter :  580 , epoch :  28 , cost :   0.5795585970610183
# time :  8.212639093399048
# 0.48391883001979885
# train_iter :  581 , epoch :  29 , cost :   0.5582671246832527
# train_iter :  582 , epoch :  29 , cost :   0.5229021231532127
# train_iter :  583 , epoch :  29 , cost :   0.5415841558532251
# train_iter :  584 , epoch :  29 , cost :   0.4271057713048906
# test_iter :  585 , epoch :  29 , cost :   0.5647389756926499
# train_iter :  586 , epoch :  29 , cost :   0.39790465349360615
# train_iter :  587 , epoch :  29 , cost :   0.5794088270355202
# train_iter :  588 , epoch :  29 , cost :   0.48262496427584234
# train_iter :  589 , epoch :  29 , cost :   0.41702696475525913
# test_iter :  590 , epoch :  29 , cost :   0.5408179035862345
# train_iter :  591 , epoch :  29 , cost :   0.5489106154791645
# train_iter :  592 , epoch :  29 , cost :   0.5159987063192052
# train_iter :  593 , epoch :  29 , cost :   0.39144496718422445
# train_iter :  594 , epoch :  29 , cost :   0.4018986942390711
# test_iter :  595 , epoch :  29 , cost :   0.47883121764427883
# train_iter :  596 , epoch :  29 , cost :   0.5382161785427912
# train_iter :  597 , epoch :  29 , cost :   0.45438023450131665
# train_iter :  598 , epoch :  29 , cost :   0.45786650467477635
# train_iter :  599 , epoch :  29 , cost :   0.5646202335716679
# test_iter :  600 , epoch :  29 , cost :   0.5972946809070853
# cross entropy :  0.5972946809070853
# time :  8.333248138427734
# 0.48751004494168915
# train_iter :  601 , epoch :  30 , cost :   0.5782579976017133
# train_iter :  602 , epoch :  30 , cost :   0.52740444658819
# train_iter :  603 , epoch :  30 , cost :   0.5419245286505245
# train_iter :  604 , epoch :  30 , cost :   0.4191979298151014
# test_iter :  605 , epoch :  30 , cost :   0.5699072596753343
# train_iter :  606 , epoch :  30 , cost :   0.39383115932483564
# train_iter :  607 , epoch :  30 , cost :   0.5957950621158468
# train_iter :  608 , epoch :  30 , cost :   0.47445914920422483
# train_iter :  609 , epoch :  30 , cost :   0.41636962016301
# test_iter :  610 , epoch :  30 , cost :   0.5429699194700227
# train_iter :  611 , epoch :  30 , cost :   0.5433957891959801
# train_iter :  612 , epoch :  30 , cost :   0.5205436715210945
# train_iter :  613 , epoch :  30 , cost :   0.3982358334495648
# train_iter :  614 , epoch :  30 , cost :   0.39671196786625584
# test_iter :  615 , epoch :  30 , cost :   0.4674561627653061
# train_iter :  616 , epoch :  30 , cost :   0.5282567546815681
# train_iter :  617 , epoch :  30 , cost :   0.45898309534372006
# train_iter :  618 , epoch :  30 , cost :   0.4588951757423213
# train_iter :  619 , epoch :  30 , cost :   0.5503403877304226
# test_iter :  620 , epoch :  30 , cost :   0.5751994603142571
# time :  8.215074062347412
# 0.48766266056214835
# train_iter :  621 , epoch :  31 , cost :   0.5544505479609478
# train_iter :  622 , epoch :  31 , cost :   0.5251692056440993
# train_iter :  623 , epoch :  31 , cost :   0.5447147997986691
# train_iter :  624 , epoch :  31 , cost :   0.4145677085215375
# test_iter :  625 , epoch :  31 , cost :   0.5560590628873768
# train_iter :  626 , epoch :  31 , cost :   0.3839550709231519
# train_iter :  627 , epoch :  31 , cost :   0.5811430994639132
# train_iter :  628 , epoch :  31 , cost :   0.46923353869872714
# train_iter :  629 , epoch :  31 , cost :   0.41902418931878416
# test_iter :  630 , epoch :  31 , cost :   0.5394690690368236
# train_iter :  631 , epoch :  31 , cost :   0.5220031165335364
# train_iter :  632 , epoch :  31 , cost :   0.5081150791718524
# train_iter :  633 , epoch :  31 , cost :   0.3954230121150861
# train_iter :  634 , epoch :  31 , cost :   0.39144296673582646
# test_iter :  635 , epoch :  31 , cost :   0.44891706248097
# train_iter :  636 , epoch :  31 , cost :   0.5124096449245615
# train_iter :  637 , epoch :  31 , cost :   0.4357143518132137
# train_iter :  638 , epoch :  31 , cost :   0.45851517449777845
# train_iter :  639 , epoch :  31 , cost :   0.5452989798770653
# test_iter :  640 , epoch :  31 , cost :   0.5628599954694826
# time :  8.362181186676025
# 0.4788237803749219
# train_iter :  641 , epoch :  32 , cost :   0.5389501117269289
# train_iter :  642 , epoch :  32 , cost :   0.5135557742208605
# train_iter :  643 , epoch :  32 , cost :   0.537659835663824
# train_iter :  644 , epoch :  32 , cost :   0.40481725949439096
# test_iter :  645 , epoch :  32 , cost :   0.5539962564117977
# train_iter :  646 , epoch :  32 , cost :   0.3783990408290087
# train_iter :  647 , epoch :  32 , cost :   0.5580959494638003
# train_iter :  648 , epoch :  32 , cost :   0.46938340098927667
# train_iter :  649 , epoch :  32 , cost :   0.40611491381709675
# test_iter :  650 , epoch :  32 , cost :   0.5377374090706373
# train_iter :  651 , epoch :  32 , cost :   0.52132767893183
# train_iter :  652 , epoch :  32 , cost :   0.5061848249325382
# train_iter :  653 , epoch :  32 , cost :   0.38259377193946675
# train_iter :  654 , epoch :  32 , cost :   0.38712315483123944
# test_iter :  655 , epoch :  32 , cost :   0.4538722598915065
# train_iter :  656 , epoch :  32 , cost :   0.5183833833569822
# train_iter :  657 , epoch :  32 , cost :   0.43181361152383957
# train_iter :  658 , epoch :  32 , cost :   0.4561518825432424
# train_iter :  659 , epoch :  32 , cost :   0.5477015825935951
# test_iter :  660 , epoch :  32 , cost :   0.5717721617552459
# time :  8.216553688049316
# 0.47239101105362
# train_iter :  661 , epoch :  33 , cost :   0.5498408378801787
# train_iter :  662 , epoch :  33 , cost :   0.5117551340800355
# train_iter :  663 , epoch :  33 , cost :   0.5381247293885825
# train_iter :  664 , epoch :  33 , cost :   0.39646601531330405
# test_iter :  665 , epoch :  33 , cost :   0.5589353754321493
# train_iter :  666 , epoch :  33 , cost :   0.37521702424155234
# train_iter :  667 , epoch :  33 , cost :   0.5651359148383407
# train_iter :  668 , epoch :  33 , cost :   0.46425579166389447
# train_iter :  669 , epoch :  33 , cost :   0.40323066457761775
# test_iter :  670 , epoch :  33 , cost :   0.5396126906998314
# train_iter :  671 , epoch :  33 , cost :   0.5218306180353925
# train_iter :  672 , epoch :  33 , cost :   0.5097618437220504
# train_iter :  673 , epoch :  33 , cost :   0.3828184567940548
# train_iter :  674 , epoch :  33 , cost :   0.3825511875719146
# test_iter :  675 , epoch :  33 , cost :   0.450871945186488
# train_iter :  676 , epoch :  33 , cost :   0.5174162590645066
# train_iter :  677 , epoch :  33 , cost :   0.43401089528334597
# train_iter :  678 , epoch :  33 , cost :   0.45406405294815455
# train_iter :  679 , epoch :  33 , cost :   0.5421656841510085
# test_iter :  680 , epoch :  33 , cost :   0.5664445822336885
# time :  8.333653688430786
# 0.4717903193471209
# train_iter :  681 , epoch :  34 , cost :   0.5421781619794764
# train_iter :  682 , epoch :  34 , cost :   0.509483188354835
# train_iter :  683 , epoch :  34 , cost :   0.5386968143706568
# train_iter :  684 , epoch :  34 , cost :   0.39027053672271494
# test_iter :  685 , epoch :  34 , cost :   0.5559246780133902
# train_iter :  686 , epoch :  34 , cost :   0.36869265276346497
# train_iter :  687 , epoch :  34 , cost :   0.5572144180058369
# train_iter :  688 , epoch :  34 , cost :   0.45880952889756543
# train_iter :  689 , epoch :  34 , cost :   0.4020824766573813
# test_iter :  690 , epoch :  34 , cost :   0.5395686166653821
# train_iter :  691 , epoch :  34 , cost :   0.5130164823646756
# train_iter :  692 , epoch :  34 , cost :   0.5065323131665624
# train_iter :  693 , epoch :  34 , cost :   0.3799196007513448
# train_iter :  694 , epoch :  34 , cost :   0.37871977089159997
# test_iter :  695 , epoch :  34 , cost :   0.442684347693932
# train_iter :  696 , epoch :  34 , cost :   0.5115554227488242
# train_iter :  697 , epoch :  34 , cost :   0.4244571891741096
# train_iter :  698 , epoch :  34 , cost :   0.45295511113372655
# train_iter :  699 , epoch :  34 , cost :   0.5384606987014755
# test_iter :  700 , epoch :  34 , cost :   0.562448494790025
# cross entropy :  0.5624484947900248
# time :  8.146655797958374
# 0.4670652729177657
# train_iter :  701 , epoch :  35 , cost :   0.53496442955441
# train_iter :  702 , epoch :  35 , cost :   0.502049330431054
# train_iter :  703 , epoch :  35 , cost :   0.5362802727534364
# train_iter :  704 , epoch :  35 , cost :   0.38367797633258943
# test_iter :  705 , epoch :  35 , cost :   0.5537114595866897
# train_iter :  706 , epoch :  35 , cost :   0.36479255685099743
# train_iter :  707 , epoch :  35 , cost :   0.547784362377621
# train_iter :  708 , epoch :  35 , cost :   0.4562355913062229
# train_iter :  709 , epoch :  35 , cost :   0.3968594990410925
# test_iter :  710 , epoch :  35 , cost :   0.5384016902800624
# train_iter :  711 , epoch :  35 , cost :   0.510987022668448
# train_iter :  712 , epoch :  35 , cost :   0.5060083342363711
# train_iter :  713 , epoch :  35 , cost :   0.3747748870390633
# train_iter :  714 , epoch :  35 , cost :   0.3740349217899913
# test_iter :  715 , epoch :  35 , cost :   0.4413112447222711
# train_iter :  716 , epoch :  35 , cost :   0.5127357531531604
# train_iter :  717 , epoch :  35 , cost :   0.42073111077555253
# train_iter :  718 , epoch :  35 , cost :   0.4503115777341431
# train_iter :  719 , epoch :  35 , cost :   0.5381212196729477
# test_iter :  720 , epoch :  35 , cost :   0.5641280987458912
# time :  8.377640724182129
# 0.4631468028573188
# train_iter :  721 , epoch :  36 , cost :   0.5354397348592143
# train_iter :  722 , epoch :  36 , cost :   0.49902771208944174
# train_iter :  723 , epoch :  36 , cost :   0.5359174491018723
# train_iter :  724 , epoch :  36 , cost :   0.3769211050442132
# test_iter :  725 , epoch :  36 , cost :   0.5555640116093312
# train_iter :  726 , epoch :  36 , cost :   0.3614298458863266
# train_iter :  727 , epoch :  36 , cost :   0.5450901110245144
# train_iter :  728 , epoch :  36 , cost :   0.45246929615753406
# train_iter :  729 , epoch :  36 , cost :   0.39345867034930804
# test_iter :  730 , epoch :  36 , cost :   0.5389968167156569
# train_iter :  731 , epoch :  36 , cost :   0.5085494416491415
# train_iter :  732 , epoch :  36 , cost :   0.5071686500214475
# train_iter :  733 , epoch :  36 , cost :   0.372671142615535
# train_iter :  734 , epoch :  36 , cost :   0.3708068091145181
# test_iter :  735 , epoch :  36 , cost :   0.4382145137406455
# train_iter :  736 , epoch :  36 , cost :   0.5116720852926719
# train_iter :  737 , epoch :  36 , cost :   0.4173476678563142
# train_iter :  738 , epoch :  36 , cost :   0.4483113443720437
# train_iter :  739 , epoch :  36 , cost :   0.5350552565906298
# test_iter :  740 , epoch :  36 , cost :   0.561153155464436
# time :  8.201751708984375
# 0.4607085201265454
# train_iter :  741 , epoch :  37 , cost :   0.5294418006494486
# train_iter :  742 , epoch :  37 , cost :   0.49490368498818726
# train_iter :  743 , epoch :  37 , cost :   0.5349227816122014
# train_iter :  744 , epoch :  37 , cost :   0.3738797482209483
# test_iter :  745 , epoch :  37 , cost :   0.5543378783518693
# train_iter :  746 , epoch :  37 , cost :   0.35768185201645863
# ...
# time :  8.04445767402649
# 0.40954691107647256
# train_iter :  1761 , epoch :  88 , cost :   0.43962519788760723
# train_iter :  1762 , epoch :  88 , cost :   0.44057892429929496
# train_iter :  1763 , epoch :  88 , cost :   0.5083880778676604
# train_iter :  1764 , epoch :  88 , cost :   0.28704570735648277
# test_iter :  1765 , epoch :  88 , cost :   0.5499814801292204
# train_iter :  1766 , epoch :  88 , cost :   0.2989040566613973
# train_iter :  1767 , epoch :  88 , cost :   0.4674949522109457
# train_iter :  1768 , epoch :  88 , cost :   0.3824829073002283
# train_iter :  1769 , epoch :  88 , cost :   0.34832832911733425
# test_iter :  1770 , epoch :  88 , cost :   0.5420486031943839
# train_iter :  1771 , epoch :  88 , cost :   0.4562060292376299
# train_iter :  1772 , epoch :  88 , cost :   0.4854221838424982
# train_iter :  1773 , epoch :  88 , cost :   0.32774149552106707
# train_iter :  1774 , epoch :  88 , cost :   0.32278603274745793
# test_iter :  1775 , epoch :  88 , cost :   0.37940540811092965
# train_iter :  1776 , epoch :  88 , cost :   0.492438004988398
# train_iter :  1777 , epoch :  88 , cost :   0.35735221174291887
# train_iter :  1778 , epoch :  88 , cost :   0.43666394826708865
# train_iter :  1779 , epoch :  88 , cost :   0.4985452766389231
# test_iter :  1780 , epoch :  88 , cost :   0.530499534863641
# time :  8.18669581413269
# 0.4093752084804333
# train_iter :  1781 , epoch :  89 , cost :   0.4393807382220292
# train_iter :  1782 , epoch :  89 , cost :   0.4404496320964391
# train_iter :  1783 , epoch :  89 , cost :   0.5082837814387126
# train_iter :  1784 , epoch :  89 , cost :   0.2868514847146468
# test_iter :  1785 , epoch :  89 , cost :   0.549909866584818
# train_iter :  1786 , epoch :  89 , cost :   0.2986516045927744
# train_iter :  1787 , epoch :  89 , cost :   0.4675087390647862
# train_iter :  1788 , epoch :  89 , cost :   0.3821589575380174
# train_iter :  1789 , epoch :  89 , cost :   0.348251573589444
# test_iter :  1790 , epoch :  89 , cost :   0.5421486046826436
# train_iter :  1791 , epoch :  89 , cost :   0.4559966992372726
# train_iter :  1792 , epoch :  89 , cost :   0.485269958695961
# train_iter :  1793 , epoch :  89 , cost :   0.327548120037387
# train_iter :  1794 , epoch :  89 , cost :   0.3226147081328783
# test_iter :  1795 , epoch :  89 , cost :   0.3792483225772578
# train_iter :  1796 , epoch :  89 , cost :   0.4922658272189208
# train_iter :  1797 , epoch :  89 , cost :   0.3572182647697268
# train_iter :  1798 , epoch :  89 , cost :   0.4364287245313547
# train_iter :  1799 , epoch :  89 , cost :   0.4985086038527946
# test_iter :  1800 , epoch :  89 , cost :   0.5304836048790359
# cross entropy :  0.530483604879036
# time :  8.052868127822876
# 0.40921171360832154
# train_iter :  1801 , epoch :  90 , cost :   0.43919030013750077
# train_iter :  1802 , epoch :  90 , cost :   0.4402494978517658
# train_iter :  1803 , epoch :  90 , cost :   0.5081781479860572
# train_iter :  1804 , epoch :  90 , cost :   0.2866604257430454
# test_iter :  1805 , epoch :  90 , cost :   0.5498833902810709
# train_iter :  1806 , epoch :  90 , cost :   0.2984277150324596
# train_iter :  1807 , epoch :  90 , cost :   0.4675897829157883
# train_iter :  1808 , epoch :  90 , cost :   0.38176291686554803
# train_iter :  1809 , epoch :  90 , cost :   0.34817733524523375
# test_iter :  1810 , epoch :  90 , cost :   0.5422748515044202
# train_iter :  1811 , epoch :  90 , cost :   0.45572900889153145
# train_iter :  1812 , epoch :  90 , cost :   0.48507280852811197
# train_iter :  1813 , epoch :  90 , cost :   0.3273246341549462
# train_iter :  1814 , epoch :  90 , cost :   0.3224265326197158
# test_iter :  1815 , epoch :  90 , cost :   0.37912202554949254
# train_iter :  1816 , epoch :  90 , cost :   0.4921728085484979
# train_iter :  1817 , epoch :  90 , cost :   0.35715072158549577
# train_iter :  1818 , epoch :  90 , cost :   0.4362802617295924
# train_iter :  1819 , epoch :  90 , cost :   0.4984774760594165
# test_iter :  1820 , epoch :  90 , cost :   0.5305349759977308
# time :  8.188561201095581
# 0.40905439836841917
# train_iter :  1821 , epoch :  91 , cost :   0.4389964429961048
# train_iter :  1822 , epoch :  91 , cost :   0.4400005615095777
# train_iter :  1823 , epoch :  91 , cost :   0.5080516934549865
# train_iter :  1824 , epoch :  91 , cost :   0.2864225664588566
# test_iter :  1825 , epoch :  91 , cost :   0.5498434587428151
# train_iter :  1826 , epoch :  91 , cost :   0.2982747711775676
# train_iter :  1827 , epoch :  91 , cost :   0.46758174618342463
# train_iter :  1828 , epoch :  91 , cost :   0.3814821206653232
# train_iter :  1829 , epoch :  91 , cost :   0.348076270563471
# test_iter :  1830 , epoch :  91 , cost :   0.5423083693359547
# train_iter :  1831 , epoch :  91 , cost :   0.4555255544699891
# train_iter :  1832 , epoch :  91 , cost :   0.48493215773870957
# train_iter :  1833 , epoch :  91 , cost :   0.3271504867728279
# train_iter :  1834 , epoch :  91 , cost :   0.3222480633966327
# test_iter :  1835 , epoch :  91 , cost :   0.37896831530079217
# train_iter :  1836 , epoch :  91 , cost :   0.49207286087230473
# train_iter :  1837 , epoch :  91 , cost :   0.35703776073999693
# train_iter :  1838 , epoch :  91 , cost :   0.436118414876937
# train_iter :  1839 , epoch :  91 , cost :   0.49842527650272817
# test_iter :  1840 , epoch :  91 , cost :   0.5305242504880713
# time :  8.119269132614136
# 0.4088997967737149
# train_iter :  1841 , epoch :  92 , cost :   0.43883078918554774
# train_iter :  1842 , epoch :  92 , cost :   0.4397957935483268
# train_iter :  1843 , epoch :  92 , cost :   0.5079316585029899
# train_iter :  1844 , epoch :  92 , cost :   0.28624424237727375
# test_iter :  1845 , epoch :  92 , cost :   0.5497739749333501
# train_iter :  1846 , epoch :  92 , cost :   0.29810411393251696
# train_iter :  1847 , epoch :  92 , cost :   0.46762074183056557
# train_iter :  1848 , epoch :  92 , cost :   0.3811553772014804
# train_iter :  1849 , epoch :  92 , cost :   0.3480262191844886
# test_iter :  1850 , epoch :  92 , cost :   0.5423721368215645
# train_iter :  1851 , epoch :  92 , cost :   0.4553397089659042
# train_iter :  1852 , epoch :  92 , cost :   0.48475873331698166
# train_iter :  1853 , epoch :  92 , cost :   0.32693046351539723
# train_iter :  1854 , epoch :  92 , cost :   0.3220599957794924
# test_iter :  1855 , epoch :  92 , cost :   0.3789138245670761
# train_iter :  1856 , epoch :  92 , cost :   0.49198575622484614
# train_iter :  1857 , epoch :  92 , cost :   0.35693573202985734
# train_iter :  1858 , epoch :  92 , cost :   0.43603245026834997
# train_iter :  1859 , epoch :  92 , cost :   0.49834804724454046
# test_iter :  1860 , epoch :  92 , cost :   0.5305493659156547
# time :  8.154415130615234
# 0.4087562389442849
# train_iter :  1861 , epoch :  93 , cost :   0.4386538122157322
# train_iter :  1862 , epoch :  93 , cost :   0.4396050584154213
# train_iter :  1863 , epoch :  93 , cost :   0.5078007567518069
# train_iter :  1864 , epoch :  93 , cost :   0.2860566865065379
# test_iter :  1865 , epoch :  93 , cost :   0.5496850817302467
# train_iter :  1866 , epoch :  93 , cost :   0.29795485344156475
# train_iter :  1867 , epoch :  93 , cost :   0.4676346344564657
# train_iter :  1868 , epoch :  93 , cost :   0.380885410060542
# train_iter :  1869 , epoch :  93 , cost :   0.34796171961989025
# test_iter :  1870 , epoch :  93 , cost :   0.5423929457146854
# train_iter :  1871 , epoch :  93 , cost :   0.4551684632828885
# train_iter :  1872 , epoch :  93 , cost :   0.4846300765262075
# train_iter :  1873 , epoch :  93 , cost :   0.32676392447844477
# train_iter :  1874 , epoch :  93 , cost :   0.3218934433510029
# test_iter :  1875 , epoch :  93 , cost :   0.3787871048735322
# train_iter :  1876 , epoch :  93 , cost :   0.49192387052128894
# train_iter :  1877 , epoch :  93 , cost :   0.3568519649222594
# train_iter :  1878 , epoch :  93 , cost :   0.43590691713630647
# train_iter :  1879 , epoch :  93 , cost :   0.49830409715287627
# test_iter :  1880 , epoch :  93 , cost :   0.5305789580235732
# time :  8.09964656829834
# 0.40862473055245224
# train_iter :  1881 , epoch :  94 , cost :   0.4385129826776892
# train_iter :  1882 , epoch :  94 , cost :   0.4393512989966045
# train_iter :  1883 , epoch :  94 , cost :   0.5076683109945053
# train_iter :  1884 , epoch :  94 , cost :   0.2858754150380436
# test_iter :  1885 , epoch :  94 , cost :   0.5496441336549058
# train_iter :  1886 , epoch :  94 , cost :   0.2978348547886357
# train_iter :  1887 , epoch :  94 , cost :   0.46765801066451135
# train_iter :  1888 , epoch :  94 , cost :   0.38061028150453086
# train_iter :  1889 , epoch :  94 , cost :   0.3479110313232715
# test_iter :  1890 , epoch :  94 , cost :   0.5424249155284919
# train_iter :  1891 , epoch :  94 , cost :   0.4550114135508076
# train_iter :  1892 , epoch :  94 , cost :   0.4844895585546197
# train_iter :  1893 , epoch :  94 , cost :   0.3266079932739709
# train_iter :  1894 , epoch :  94 , cost :   0.32173738407570995
# test_iter :  1895 , epoch :  94 , cost :   0.37868360699153897
# train_iter :  1896 , epoch :  94 , cost :   0.4918561676040411
# train_iter :  1897 , epoch :  94 , cost :   0.35675550416797946
# train_iter :  1898 , epoch :  94 , cost :   0.43581741956400466
# train_iter :  1899 , epoch :  94 , cost :   0.49824595600826754
# test_iter :  1900 , epoch :  94 , cost :   0.5305986802274617
# cross entropy :  0.5305986802274617
# time :  8.225095272064209
# 0.4084964739241995
# train_iter :  1901 , epoch :  95 , cost :   0.43836852896279127
# train_iter :  1902 , epoch :  95 , cost :   0.4391290716523932
# train_iter :  1903 , epoch :  95 , cost :   0.5075421936345056
# train_iter :  1904 , epoch :  95 , cost :   0.2856846971969728
# test_iter :  1905 , epoch :  95 , cost :   0.5495925445604267
# train_iter :  1906 , epoch :  95 , cost :   0.2977189493641959
# train_iter :  1907 , epoch :  95 , cost :   0.4676277750853987
# train_iter :  1908 , epoch :  95 , cost :   0.3803881479218716
# train_iter :  1909 , epoch :  95 , cost :   0.34785906543925477
# test_iter :  1910 , epoch :  95 , cost :   0.5424321240907558
# train_iter :  1911 , epoch :  95 , cost :   0.4548841949590814
# train_iter :  1912 , epoch :  95 , cost :   0.4843737080372954
# train_iter :  1913 , epoch :  95 , cost :   0.3264686105028191
# train_iter :  1914 , epoch :  95 , cost :   0.32158648354959524
# test_iter :  1915 , epoch :  95 , cost :   0.3785622906801543
# train_iter :  1916 , epoch :  95 , cost :   0.4918186684439918
# train_iter :  1917 , epoch :  95 , cost :   0.35666586895359387
# train_iter :  1918 , epoch :  95 , cost :   0.43571605910651084
# train_iter :  1919 , epoch :  95 , cost :   0.4982013578248302
# test_iter :  1920 , epoch :  95 , cost :   0.5306204888646526
# time :  8.021605253219604
# 0.4083770862896938
# train_iter :  1921 , epoch :  96 , cost :   0.4382356103191634
# train_iter :  1922 , epoch :  96 , cost :   0.4389023809819664
# train_iter :  1923 , epoch :  96 , cost :   0.507427889989252
# train_iter :  1924 , epoch :  96 , cost :   0.28551632746599337
# test_iter :  1925 , epoch :  96 , cost :   0.549556556729837
# train_iter :  1926 , epoch :  96 , cost :   0.29760124384387554
# train_iter :  1927 , epoch :  96 , cost :   0.4676354093218161
# train_iter :  1928 , epoch :  96 , cost :   0.3801386307821574
# train_iter :  1929 , epoch :  96 , cost :   0.34781896889781316
# test_iter :  1930 , epoch :  96 , cost :   0.542469397875882
# train_iter :  1931 , epoch :  96 , cost :   0.454753709108507
# train_iter :  1932 , epoch :  96 , cost :   0.484252422696991
# train_iter :  1933 , epoch :  96 , cost :   0.32630896766731426
# train_iter :  1934 , epoch :  96 , cost :   0.32144153147421617
# test_iter :  1935 , epoch :  96 , cost :   0.37849169264135457
# train_iter :  1936 , epoch :  96 , cost :   0.4917873492043988
# train_iter :  1937 , epoch :  96 , cost :   0.35657578810496715
# train_iter :  1938 , epoch :  96 , cost :   0.43565269801290524
# train_iter :  1939 , epoch :  96 , cost :   0.49813249326582193
# test_iter :  1940 , epoch :  96 , cost :   0.5306262600938877
# time :  8.221580028533936
# 0.40826133882107246
# train_iter :  1941 , epoch :  97 , cost :   0.4380915892425516
# train_iter :  1942 , epoch :  97 , cost :   0.43875229666683974
# train_iter :  1943 , epoch :  97 , cost :   0.5073244783385982
# train_iter :  1944 , epoch :  97 , cost :   0.28536476569737906
# test_iter :  1945 , epoch :  97 , cost :   0.5494993159984511
# train_iter :  1946 , epoch :  97 , cost :   0.2974687201456051
# train_iter :  1947 , epoch :  97 , cost :   0.4676401750553495
# train_iter :  1948 , epoch :  97 , cost :   0.3799038082679782
# train_iter :  1949 , epoch :  97 , cost :   0.3477804679535422
# test_iter :  1950 , epoch :  97 , cost :   0.5424993211765342
# train_iter :  1951 , epoch :  97 , cost :   0.4546364903795148
# train_iter :  1952 , epoch :  97 , cost :   0.4841505163809163
# train_iter :  1953 , epoch :  97 , cost :   0.32616909341213757
# train_iter :  1954 , epoch :  97 , cost :   0.3213071754678643
# test_iter :  1955 , epoch :  97 , cost :   0.3783792425583135
# train_iter :  1956 , epoch :  97 , cost :   0.49175699825352615
# train_iter :  1957 , epoch :  97 , cost :   0.35649492103422165
# train_iter :  1958 , epoch :  97 , cost :   0.4355425729410073
# train_iter :  1959 , epoch :  97 , cost :   0.49809141479340474
# test_iter :  1960 , epoch :  97 , cost :   0.5306583990277565
# time :  8.041881084442139
# 0.40815471775190226
# train_iter :  1961 , epoch :  98 , cost :   0.4379869111922588
# train_iter :  1962 , epoch :  98 , cost :   0.4385266112439192
# train_iter :  1963 , epoch :  98 , cost :   0.5072220388671704
# train_iter :  1964 , epoch :  98 , cost :   0.2852136871480557
# test_iter :  1965 , epoch :  98 , cost :   0.5494701405306739
# train_iter :  1966 , epoch :  98 , cost :   0.29736919715392207
# train_iter :  1967 , epoch :  98 , cost :   0.4676344658879604
# train_iter :  1968 , epoch :  98 , cost :   0.3796921847260647
# train_iter :  1969 , epoch :  98 , cost :   0.3477454831133042
# test_iter :  1970 , epoch :  98 , cost :   0.542540482500851
# train_iter :  1971 , epoch :  98 , cost :   0.454516085048956
# train_iter :  1972 , epoch :  98 , cost :   0.4840413616034524
# train_iter :  1973 , epoch :  98 , cost :   0.32602716864680475
# train_iter :  1974 , epoch :  98 , cost :   0.3211872071834128
# test_iter :  1975 , epoch :  98 , cost :   0.3782922216725852
# train_iter :  1976 , epoch :  98 , cost :   0.491741543171959
# train_iter :  1977 , epoch :  98 , cost :   0.35642729894547975
# train_iter :  1978 , epoch :  98 , cost :   0.4354737658525616
# train_iter :  1979 , epoch :  98 , cost :   0.4980480347893206
# test_iter :  1980 , epoch :  98 , cost :   0.5306930221943218
# time :  8.245972633361816
# 0.40805331528591265
# train_iter :  1981 , epoch :  99 , cost :   0.437858364168513
# train_iter :  1982 , epoch :  99 , cost :   0.43835680092807067
# train_iter :  1983 , epoch :  99 , cost :   0.5071213902478496
# train_iter :  1984 , epoch :  99 , cost :   0.285060075303915
# test_iter :  1985 , epoch :  99 , cost :   0.5494358975124859
# train_iter :  1986 , epoch :  99 , cost :   0.29727381947447573
# train_iter :  1987 , epoch :  99 , cost :   0.4676269897486937
# train_iter :  1988 , epoch :  99 , cost :   0.37949291555214065
# train_iter :  1989 , epoch :  99 , cost :   0.34771015025158875
# test_iter :  1990 , epoch :  99 , cost :   0.5425635934765123
# train_iter :  1991 , epoch :  99 , cost :   0.454406075302537
# train_iter :  1992 , epoch :  99 , cost :   0.4839528242909171
# train_iter :  1993 , epoch :  99 , cost :   0.32590194211324897
# train_iter :  1994 , epoch :  99 , cost :   0.3210746669490803
# test_iter :  1995 , epoch :  99 , cost :   0.3781901438407844
# train_iter :  1996 , epoch :  99 , cost :   0.49172234990105196
# train_iter :  1997 , epoch :  99 , cost :   0.35635279543362375
# train_iter :  1998 , epoch :  99 , cost :   0.4353901363816853
# train_iter :  1999 , epoch :  99 , cost :   0.4980081441596191
# test_iter :  2000 , epoch :  99 , cost :   0.5307178867212357
# cross entropy :  0.5307178867212355
# model saved to 'save/GCN+a+g_5_activity_atomwise_512_AID1478_train.ckpt'
# time :  8.51364541053772
# 0.4079568400129382
# Finish training! Total required time for training :  864.7409937381744

# %%
# plot cost versus epoch 
from matplotlib import pyplot

epochs = np.arange(1, FLAGS.epoch_size+1, 1)

pyplot.plot(epochs,train_cost, label='train')
pyplot.plot(epochs,test_cost, label='valid')
pyplot.xlabel('epoch')
pyplot.ylabel('cross entropy')
pyplot.legend(loc='upper right', fontsize=13, frameon=False)
pyplot.savefig("cost_vs_epoch.png")
pyplot.close()

# %%
from eval import train_valid_split
from eval import pred_batches
from eval import loadTest

# load tran valid and test 
train_set, valid_set = train_valid_split(model, FLAGS, modelName)

test_database = 'AID1478_test'
test_set = loadTest(model, FLAGS, modelName, test_database, test_numDB)

# extract predictions out of batches 
Preds_train_set = pred_batches(model, train_set, FLAGS)
Preds_valid_set = pred_batches(model, valid_set, FLAGS)
Preds_test_set = pred_batches(model, test_set, FLAGS)

# %%
# calculate accuracy score
accuracy = accuracy_score(valid_set[2], Preds_valid_set.round())
print ("valid accuracy: ", accuracy)

accuracy = accuracy_score(test_set[2], Preds_test_set.round())
print ("test accuracy: ", accuracy)

# calculate auc score & plot roc curve 
fpr, tpr, _ = roc_curve(valid_set[2], Preds_valid_set)
auc = roc_auc_score(valid_set[2], Preds_valid_set)
print ("valid AUC: ", auc)

pyplot.plot(fpr, tpr, marker='.', label='AUC = {:0.3f}'.format(auc))
pyplot.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend(loc='lower right', fontsize=13, frameon=False)
# save the plot
pyplot.savefig('roc_curve_valid.png')
pyplot.close()

fpr, tpr, _ = roc_curve(test_set[2], Preds_test_set)
auc = roc_auc_score(test_set[2], Preds_test_set)
print ("test AUC: ", auc)

pyplot.plot(fpr, tpr, marker='.', label='AUC = {:0.3f}'.format(auc))
pyplot.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend(loc='lower right', fontsize=13, frameon=False)
# save the plot
pyplot.savefig('roc_curve_test.png')
# Out:
# valid accuracy:  0.79
# test accuracy:  0.8505208333333333
# valid AUC:  0.8077987421383648
# test AUC:  0.8028043167670091
